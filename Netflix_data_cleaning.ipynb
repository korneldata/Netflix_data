# %%
import pandas as pnd

# %%
# reading csv file
netflix = pnd.read_csv('C:/Users/Nowy_użytkownik/Desktop/netflix.csv')

# %%
# overwiew of the data
netflix.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %%
netflix.shape
# Out:
# (8790, 10)

# %%
# loooking for duplicated values
netflix.duplicated().sum()
# Out:
# 0

# %%
# removing unnecessary column 
netflix = netflix.drop('show_id', axis = 1)

# %%
# checking data types 
netflix.dtypes
# Out:
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
# converting 'date_added' column values to datetime type
netflix['date_added'] = pnd.to_datetime(netflix['date_added'])

# %%
# conversion succeded
netflix.dtypes
# Out:
# type                    object
# title                   object
# director                object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# dtype: object

# %%
# copying data from 'duration' column to new column 'seasons_count'
netflix['seasons_count'] = netflix['duration']

# %%
# replacing unnecessary data from 'duration' column with '0'
netflix['duration'] = netflix['duration'].str.replace('.+Season.*','0')
# Out:
# C:\Users\Nowy_użytkownik\AppData\Local\Temp\ipykernel_12804\4165232788.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   netflix['duration'] = netflix['duration'].str.replace('.+Season.*','0')

# %%
# removing 'min' from 'duration' column
netflix['duration'] = netflix['duration'].str.replace('\smin','')
# Out:
# C:\Users\Nowy_użytkownik\AppData\Local\Temp\ipykernel_12804\1723670806.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   netflix['duration'] = netflix['duration'].str.replace('\smin','')

# %%
netflix
# Out:
#          type                             title         director  \
# 0       Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show                         Ganglands  Julien Leclercq
# 2     TV Show                     Midnight Mass    Mike Flanagan
# 3       Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4       Movie                           Sankofa     Haile Gerima
# ...       ...                               ...              ...
# 8785  TV Show                        Yunus Emre        Not Given
# 8786  TV Show                         Zak Storm        Not Given
# 8787  TV Show                Zindagi Gulzar Hai        Not Given
# 8788  TV Show                              Yoko        Not Given
# 8789  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating duration  \
# 0     United States 2021-09-25          2020  PG-13       90
# 1            France 2021-09-24          2021  TV-MA        0
# 2     United States 2021-09-24          2021  TV-MA        0
# 3            Brazil 2021-09-22          2021  TV-PG       91
# 4     United States 2021-09-24          1993  TV-MA      125
# ...             ...        ...           ...    ...      ...
# 8785         Turkey 2017-01-17          2016  TV-PG        0
# 8786  United States 2018-09-13          2016  TV-Y7        0
# 8787       Pakistan 2016-12-15          2012  TV-PG        0
# 8788       Pakistan 2018-06-23          2016   TV-Y        0
# 8789       Pakistan 2018-06-07          2016  TV-Y7        0
#
#                                               listed_in seasons_count
# 0                                         Documentaries        90 min
# 1     Crime TV Shows, International TV Shows, TV Act...      1 Season
# 2                    TV Dramas, TV Horror, TV Mysteries      1 Season
# 3                    Children & Family Movies, Comedies        91 min
# 4      Dramas, Independent Movies, International Movies       125 min
# ...                                                 ...           ...
# 8785                  International TV Shows, TV Dramas     2 Seasons
# 8786                                           Kids' TV     3 Seasons
# 8787  International TV Shows, Romantic TV Shows, TV ...      1 Season
# 8788                                           Kids' TV      1 Season
# 8789                                           Kids' TV      1 Season
#
# [8790 rows x 10 columns]

# %%
# replacing unnecessary data from 'seasons_count' column with '0'
netflix['seasons_count'] = netflix['seasons_count'].str.replace('\d+\smin','0')
# Out:
# C:\Users\Nowy_użytkownik\AppData\Local\Temp\ipykernel_12804\3610559531.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   netflix['seasons_count'] = netflix['seasons_count'].str.replace('\d+\smin','0')

# %%
# removing 'Season(s)' from 'seasons_count' column
netflix['seasons_count'] = netflix['seasons_count'].str.replace('\sSeason.?','')
# Out:
# C:\Users\Nowy_użytkownik\AppData\Local\Temp\ipykernel_12804\1206745382.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   netflix['seasons_count'] = netflix['seasons_count'].str.replace('\sSeason.?','')

# %%
netflix
# Out:
#          type                             title         director  \
# 0       Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show                         Ganglands  Julien Leclercq
# 2     TV Show                     Midnight Mass    Mike Flanagan
# 3       Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4       Movie                           Sankofa     Haile Gerima
# ...       ...                               ...              ...
# 8785  TV Show                        Yunus Emre        Not Given
# 8786  TV Show                         Zak Storm        Not Given
# 8787  TV Show                Zindagi Gulzar Hai        Not Given
# 8788  TV Show                              Yoko        Not Given
# 8789  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating duration  \
# 0     United States 2021-09-25          2020  PG-13       90
# 1            France 2021-09-24          2021  TV-MA        0
# 2     United States 2021-09-24          2021  TV-MA        0
# 3            Brazil 2021-09-22          2021  TV-PG       91
# 4     United States 2021-09-24          1993  TV-MA      125
# ...             ...        ...           ...    ...      ...
# 8785         Turkey 2017-01-17          2016  TV-PG        0
# 8786  United States 2018-09-13          2016  TV-Y7        0
# 8787       Pakistan 2016-12-15          2012  TV-PG        0
# 8788       Pakistan 2018-06-23          2016   TV-Y        0
# 8789       Pakistan 2018-06-07          2016  TV-Y7        0
#
#                                               listed_in seasons_count
# 0                                         Documentaries             0
# 1     Crime TV Shows, International TV Shows, TV Act...             1
# 2                    TV Dramas, TV Horror, TV Mysteries             1
# 3                    Children & Family Movies, Comedies             0
# 4      Dramas, Independent Movies, International Movies             0
# ...                                                 ...           ...
# 8785                  International TV Shows, TV Dramas             2
# 8786                                           Kids' TV             3
# 8787  International TV Shows, Romantic TV Shows, TV ...             1
# 8788                                           Kids' TV             1
# 8789                                           Kids' TV             1
#
# [8790 rows x 10 columns]

# %%
# renaming column 
netflix = netflix.rename(columns = {'duration':'duration_min'})

# %%
netflix.dtypes
# Out:
# type                     object
# title                    object
# director                 object
# country                  object
# date_added       datetime64[ns]
# release_year              int64
# rating                   object
# duration_min             object
# listed_in                object
# seasons_count            object
# dtype: object

# %%
# changing datatype in 'duration_min' column to integer
netflix['duration_min'] = netflix['duration_min'].astype(int)

# %%
# datatype successfully changed
netflix.dtypes
# Out:
# type                     object
# title                    object
# director                 object
# country                  object
# date_added       datetime64[ns]
# release_year              int64
# rating                   object
# duration_min              int32
# listed_in                object
# seasons_count            object
# dtype: object

# %%
# changing datatype in 'seasons_count' column to integer
netflix['seasons_count'] = netflix['seasons_count'].astype(int)

# %%
# datatype successfully changed
netflix.dtypes
# Out:
# type                     object
# title                    object
# director                 object
# country                  object
# date_added       datetime64[ns]
# release_year              int64
# rating                   object
# duration_min              int32
# listed_in                object
# seasons_count             int32
# dtype: object

# %%
# looking for null values
netflix.isna().sum()
# Out:
# type             0
# title            0
# director         0
# country          0
# date_added       0
# release_year     0
# rating           0
# duration_min     0
# listed_in        0
# seasons_count    0
# dtype: int64

# %%
# changing order of columns
netflix = netflix.iloc[:,[1,0,2,3,4,5,6,7,9,8]]

# %%
# dataset after cleaning
netflix
# Out:
#                                  title     type         director  \
# 0                 Dick Johnson Is Dead    Movie  Kirsten Johnson
# 1                            Ganglands  TV Show  Julien Leclercq
# 2                        Midnight Mass  TV Show    Mike Flanagan
# 3     Confessions of an Invisible Girl    Movie    Bruno Garotti
# 4                              Sankofa    Movie     Haile Gerima
# ...                                ...      ...              ...
# 8785                        Yunus Emre  TV Show        Not Given
# 8786                         Zak Storm  TV Show        Not Given
# 8787                Zindagi Gulzar Hai  TV Show        Not Given
# 8788                              Yoko  TV Show        Not Given
# 8789                               YOM  TV Show        Not Given
#
#             country date_added  release_year rating  duration_min  \
# 0     United States 2021-09-25          2020  PG-13            90
# 1            France 2021-09-24          2021  TV-MA             0
# 2     United States 2021-09-24          2021  TV-MA             0
# 3            Brazil 2021-09-22          2021  TV-PG            91
# 4     United States 2021-09-24          1993  TV-MA           125
# ...             ...        ...           ...    ...           ...
# 8785         Turkey 2017-01-17          2016  TV-PG             0
# 8786  United States 2018-09-13          2016  TV-Y7             0
# 8787       Pakistan 2016-12-15          2012  TV-PG             0
# 8788       Pakistan 2018-06-23          2016   TV-Y             0
# 8789       Pakistan 2018-06-07          2016  TV-Y7             0
#
#       seasons_count                                          listed_in
# 0                 0                                      Documentaries
# 1                 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 1                 TV Dramas, TV Horror, TV Mysteries
# 3                 0                 Children & Family Movies, Comedies
# 4                 0   Dramas, Independent Movies, International Movies
# ...             ...                                                ...
# 8785              2                  International TV Shows, TV Dramas
# 8786              3                                           Kids' TV
# 8787              1  International TV Shows, Romantic TV Shows, TV ...
# 8788              1                                           Kids' TV
# 8789              1                                           Kids' TV
#
# [8790 rows x 10 columns]
